# %% [markdown]
# ## EY Data Challenge - Landsat Land Surface Temperature
#
# This sample notebook can be used to create a Landsat Land Surface Temperature (LST) product. The notebook creates a cloud-filtered median mosaic for any time period and location and then creates the LST product. A median mosaic reflects the "median" value of pixels for all spectral bands in the time series. When scenes within a time series contain clouds, the use of a median calculation can statistically remove clouds from the final median mosaic product, assuming there are plenty of clear pixels within the time series. The baseline data is [Landsat Collection-2 Level-2](https://www.usgs.gov/landsat-missions/landsat-collection-2) data from the MS Planetary Computer catalog.

# %%
pip install rioxarray
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rioxarray in c:\users\athar\appdata\roaming\python\python311\site-packages (0.18.2)
# Requirement already satisfied: packaging in c:\users\athar\appdata\roaming\python\python311\site-packages (from rioxarray) (24.2)
# Requirement already satisfied: rasterio>=1.3.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rioxarray) (1.4.3)
# Requirement already satisfied: xarray>=2024.7.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rioxarray) (2025.1.2)
# Requirement already satisfied: pyproj>=3.3 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rioxarray) (3.7.1)
# Requirement already satisfied: numpy>=1.23 in c:\programdata\anaconda3\lib\site-packages (from rioxarray) (1.24.3)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from pyproj>=3.3->rioxarray) (2023.7.22)
# Requirement already satisfied: affine in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio>=1.3.7->rioxarray) (2.4.0)
# Requirement already satisfied: attrs in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio>=1.3.7->rioxarray) (25.1.0)
# Requirement already satisfied: click>=4.0 in c:\programdata\anaconda3\lib\site-packages (from rasterio>=1.3.7->rioxarray) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio>=1.3.7->rioxarray) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio>=1.3.7->rioxarray) (1.1.1)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from rasterio>=1.3.7->rioxarray) (3.0.9)
# Requirement already satisfied: pandas>=2.1 in c:\users\athar\appdata\roaming\python\python311\site-packages (from xarray>=2024.7.0->rioxarray) (2.2.3)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=4.0->rasterio>=1.3.7->rioxarray) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pandas>=2.1->xarray>=2024.7.0->rioxarray) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray>=2024.7.0->rioxarray) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install odc-stac
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: odc-stac in c:\users\athar\appdata\roaming\python\python311\site-packages (0.3.11)
# Requirement already satisfied: affine in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (2.4.0)
# Requirement already satisfied: odc-geo>=0.4.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (0.4.9.post0)
# Requirement already satisfied: rasterio!=1.3.0,!=1.3.1,>=1.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (1.4.3)
# Requirement already satisfied: dask[array] in c:\programdata\anaconda3\lib\site-packages (from odc-stac) (2023.6.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\programdata\anaconda3\lib\site-packages (from odc-stac) (1.24.3)
# Requirement already satisfied: pandas in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (2.2.3)
# Requirement already satisfied: pystac<2,>=1.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (1.12.2)
# Requirement already satisfied: toolz in c:\programdata\anaconda3\lib\site-packages (from odc-stac) (0.12.0)
# Requirement already satisfied: xarray>=0.19 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (2025.1.2)
# Requirement already satisfied: cachetools in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-geo>=0.4.7->odc-stac) (5.5.0)
# Requirement already satisfied: pyproj>=3.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-geo>=0.4.7->odc-stac) (3.7.1)
# Requirement already satisfied: shapely in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-geo>=0.4.7->odc-stac) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from pystac<2,>=1.0.0->odc-stac) (2.8.2)
# Requirement already satisfied: attrs in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (25.1.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (2023.7.22)
# Requirement already satisfied: click>=4.0 in c:\programdata\anaconda3\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (1.1.1)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (3.0.9)
# Requirement already satisfied: packaging>=23.2 in c:\users\athar\appdata\roaming\python\python311\site-packages (from xarray>=0.19->odc-stac) (24.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->odc-stac) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pandas->odc-stac) (2024.1)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (2023.3.0)
# Requirement already satisfied: partd>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (6.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (6.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=4.0->rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[array]->odc-stac) (3.11.0)
# Requirement already satisfied: locket in c:\programdata\anaconda3\lib\site-packages (from partd>=1.2.0->dask[array]->odc-stac) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->pystac<2,>=1.0.0->odc-stac) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xarray
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xarray in c:\users\athar\appdata\roaming\python\python311\site-packages (2025.1.2)
# Requirement already satisfied: numpy>=1.24 in c:\programdata\anaconda3\lib\site-packages (from xarray) (1.24.3)
# Requirement already satisfied: packaging>=23.2 in c:\users\athar\appdata\roaming\python\python311\site-packages (from xarray) (24.2)
# Requirement already satisfied: pandas>=2.1 in c:\users\athar\appdata\roaming\python\python311\site-packages (from xarray) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.1->xarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.1->xarray) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pandas>=2.1->xarray) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rasterio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: rasterio in c:\users\athar\appdata\roaming\python\python311\site-packages (1.4.3)
# Requirement already satisfied: affine in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio) (25.1.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in c:\programdata\anaconda3\lib\site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in c:\programdata\anaconda3\lib\site-packages (from rasterio) (1.24.3)
# Requirement already satisfied: click-plugins in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from rasterio) (3.0.9)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=4.0->rasterio) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install stackstac
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stackstac in c:\users\athar\appdata\roaming\python\python311\site-packages (0.5.1)
# Requirement already satisfied: dask[array]>=2022.1.1 in c:\programdata\anaconda3\lib\site-packages (from stackstac) (2023.6.0)
# Requirement already satisfied: numpy<3,>1.23 in c:\programdata\anaconda3\lib\site-packages (from stackstac) (1.24.3)
# Requirement already satisfied: pandas<3,>=2 in c:\users\athar\appdata\roaming\python\python311\site-packages (from stackstac) (2.2.3)
# Requirement already satisfied: pyproj<4.0.0,>=3.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from stackstac) (3.7.1)
# Requirement already satisfied: rasterio<2.0.0,>=1.3.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from stackstac) (1.4.3)
# Requirement already satisfied: xarray>=0.18 in c:\users\athar\appdata\roaming\python\python311\site-packages (from stackstac) (2025.1.2)
# Requirement already satisfied: click>=8.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (2023.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from dask[array]>=2022.1.1->stackstac) (24.2)
# Requirement already satisfied: partd>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<3,>=2->stackstac) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<3,>=2->stackstac) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pandas<3,>=2->stackstac) (2024.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from pyproj<4.0.0,>=3.0.0->stackstac) (2023.7.22)
# Requirement already satisfied: affine in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (2.4.0)
# Requirement already satisfied: attrs in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (25.1.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (1.1.1)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (3.0.9)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.0->dask[array]>=2022.1.1->stackstac) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[array]>=2022.1.1->stackstac) (3.11.0)
# Requirement already satisfied: locket in c:\programdata\anaconda3\lib\site-packages (from partd>=1.2.0->dask[array]>=2022.1.1->stackstac) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=2->stackstac) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pystac-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pystac-client in c:\users\athar\appdata\roaming\python\python311\site-packages (0.8.6)
# Requirement already satisfied: requests>=2.28.2 in c:\programdata\anaconda3\lib\site-packages (from pystac-client) (2.31.0)
# Requirement already satisfied: pystac[validation]>=1.10.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pystac-client) (1.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pystac-client) (2.8.2)
# Requirement already satisfied: jsonschema~=4.18 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pystac[validation]>=1.10.0->pystac-client) (4.23.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pystac-client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.28.2->pystac-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.28.2->pystac-client) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.28.2->pystac-client) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.28.2->pystac-client) (2023.7.22)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\athar\appdata\roaming\python\python311\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\athar\appdata\roaming\python\python311\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\athar\appdata\roaming\python\python311\site-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (0.23.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from referencing>=0.28.4->jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install planetary-computer
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: planetary-computer in c:\users\athar\appdata\roaming\python\python311\site-packages (1.0.0)
# Requirement already satisfied: click>=7.1 in c:\programdata\anaconda3\lib\site-packages (from planetary-computer) (8.0.4)
# Requirement already satisfied: pydantic>=1.7.3 in c:\users\athar\appdata\roaming\python\python311\site-packages (from planetary-computer) (2.9.2)
# Requirement already satisfied: pystac>=1.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from planetary-computer) (1.12.2)
# Requirement already satisfied: pystac-client>=0.2.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from planetary-computer) (0.8.6)
# Requirement already satisfied: pytz>=2020.5 in c:\programdata\anaconda3\lib\site-packages (from planetary-computer) (2022.7)
# Requirement already satisfied: requests>=2.25.1 in c:\programdata\anaconda3\lib\site-packages (from planetary-computer) (2.31.0)
# Requirement already satisfied: packaging in c:\users\athar\appdata\roaming\python\python311\site-packages (from planetary-computer) (24.2)
# Requirement already satisfied: python-dotenv in c:\users\athar\appdata\roaming\python\python311\site-packages (from planetary-computer) (1.0.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=7.1->planetary-computer) (0.4.6)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pydantic>=1.7.3->planetary-computer) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pydantic>=1.7.3->planetary-computer) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pydantic>=1.7.3->planetary-computer) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from pystac>=1.0.0->planetary-computer) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.1->planetary-computer) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.1->planetary-computer) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.1->planetary-computer) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.25.1->planetary-computer) (2023.7.22)
# Requirement already satisfied: jsonschema~=4.18 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pystac>=1.0.0->planetary-computer) (4.23.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->pystac>=1.0.0->planetary-computer) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from jsonschema~=4.18->pystac>=1.0.0->planetary-computer) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\athar\appdata\roaming\python\python311\site-packages (from jsonschema~=4.18->pystac>=1.0.0->planetary-computer) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\athar\appdata\roaming\python\python311\site-packages (from jsonschema~=4.18->pystac>=1.0.0->planetary-computer) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\athar\appdata\roaming\python\python311\site-packages (from jsonschema~=4.18->pystac>=1.0.0->planetary-computer) (0.23.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Supress Warnings 
import warnings
warnings.filterwarnings('ignore')

# Import common GIS tools
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import rioxarray as rio
import rasterio
from matplotlib.cm import jet,RdYlGn

# Import Planetary Computer tools
import stackstac
import pystac_client
import planetary_computer 
from odc.stac import stac_load
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 17
#      15 import pystac_client
#      16 import planetary_computer
# ---> 17 from odc.stac import stac_load
#
# File ~\AppData\Roaming\Python\Python311\site-packages\odc\stac\__init__.py:4
#       1 """STAC Item -> ODC Dataset[eo3]."""
#       3 from ._version import __version__  # isort:skip  this has to be 1st import
# ----> 4 from odc.loader._rio import configure_rio, configure_s3_access
#       5 from odc.loader.types import RasterBandMetadata, RasterLoadParams, RasterSource
#       7 from ._mdtools import (
#       8     ConversionConfig,
#       9     ParsedItem,
#    (...)
#      13     parse_items,
#      14 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\odc\loader\__init__.py:5
#       1 """
#       2 Tools for constructing xarray objects from parsed metadata.
#       3 """
# ----> 5 from ._builder import chunked_load, resolve_chunk_shape
#       6 from ._driver import reader_driver, register_driver, unregister_driver
#       7 from ._reader import (
#       8     resolve_dst_dtype,
#       9     resolve_dst_nodata,
#      10     resolve_load_cfg,
#      11     resolve_src_nodata,
#      12 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\odc\loader\_builder.py:32
#      30 from dask.base import quote, tokenize
#      31 from dask.highlevelgraph import HighLevelGraph
# ---> 32 from dask.typing import Key
#      33 from numpy.typing import DTypeLike
#      34 from odc.geo.geobox import GeoBox, GeoBoxBase, GeoboxTiles
#
# ImportError: cannot import name 'Key' from 'dask.typing' (C:\ProgramData\anaconda3\Lib\site-packages\dask\typing.py)

# %% [markdown]
# ### Discover and load the data for analysis
#
# First, we define our area of interest using latitude and longitude coordinates.

# %%
# Define the bounding box for the entire data region using (Latitude, Longitude)
# This is the region of New York City that contains our temperature dataset
lower_left = (40.75, -74.01)
upper_right = (40.88, -73.86)

# %%
# Calculate the bounds for doing an archive data search
# bounds = (min_lon, min_lat, max_lon, max_lat)
bounds = (lower_left[1], lower_left[0], upper_right[1], upper_right[0])

# %%
# Define the time window
# We will use a period of 3 months to search for data
time_window = "2021-06-01/2021-09-01"

# %% [markdown]
# Using the `pystac_client` we can search the Planetary Computer's STAC endpoint for items matching our query parameters. The query searches for "low cloud" scenes with overall cloud cover <20%. We will also limit our search to Landsat-8 to avoid the Landsat-7 scan line corrector failure. The result is the number of scenes matching our search criteria that touch our area of interest. Some of these may be partial scenes or contain clouds.

# %%
stac = pystac_client.Client.open("https://planetarycomputer.microsoft.com/api/stac/v1")

search = stac.search(
    bbox=bounds, 
    datetime=time_window,
    collections=["landsat-c2-l2"],
    query={"eo:cloud_cover": {"lt": 50},"platform": {"in": ["landsat-8"]}},
)

# %%
items = list(search.get_items())
print('This is the number of scenes that touch our region:',len(items))
# Out:
# This is the number of scenes that touch our region: 8

# %% [markdown]
# Next, we'll load the data into an [xarray](https://xarray.pydata.org/en/stable/) DataArray using [stackstac](https://stackstac.readthedocs.io/). We will only keep the commonly used spectral bands (Red, Green, Blue, NIR, Surface Temperature). There are also several other <b>important settings for the data</b>: We have changed the projection to epsg=4326 which is standard latitude-longitude in degrees. We have specified the spatial resolution of each pixel to be 30-meters.

# %%
signed_items = [planetary_computer.sign(item).to_dict() for item in items]

# %%
# Define the pixel resolution for the final product
# Define the scale according to our selected crs, so we will use degrees
resolution = 30  # meters per pixel 
scale = resolution / 111320.0 # degrees per pixel for crs=4326

# %% [markdown]
# ### Landsat Band Summary
# The following list of bands will be loaded by the Open Data Cube (ODC) stac command:<br>
# We will use two load commands to separate the RGB data from the Surface Temperature data.<br><br>
# Band 2 = blue = 30m<br>
# Band 3 = green = 30m<br>
# Band 4 = red = 30m<br>
# Band 5 = nir08 (near infrared) = 30m<br>
# Band 11 = Surface Temperature = lwir11 = 100m

# %%
pip install odc-stac --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: odc-stac in c:\users\athar\appdata\roaming\python\python311\site-packages (0.3.11)
# Requirement already satisfied: affine in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (2.4.0)
# Requirement already satisfied: odc-geo>=0.4.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (0.4.9.post0)
# Requirement already satisfied: rasterio!=1.3.0,!=1.3.1,>=1.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (1.4.3)
# Requirement already satisfied: dask[array] in c:\programdata\anaconda3\lib\site-packages (from odc-stac) (2023.6.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\programdata\anaconda3\lib\site-packages (from odc-stac) (1.24.3)
# Requirement already satisfied: pandas in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (2.2.3)
# Requirement already satisfied: pystac<2,>=1.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (1.12.2)
# Requirement already satisfied: toolz in c:\programdata\anaconda3\lib\site-packages (from odc-stac) (0.12.0)
# Requirement already satisfied: xarray>=0.19 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-stac) (2025.1.2)
# Requirement already satisfied: cachetools in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-geo>=0.4.7->odc-stac) (5.5.0)
# Requirement already satisfied: pyproj>=3.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-geo>=0.4.7->odc-stac) (3.7.1)
# Requirement already satisfied: shapely in c:\users\athar\appdata\roaming\python\python311\site-packages (from odc-geo>=0.4.7->odc-stac) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\programdata\anaconda3\lib\site-packages (from pystac<2,>=1.0.0->odc-stac) (2.8.2)
# Requirement already satisfied: attrs in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (25.1.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (2023.7.22)
# Requirement already satisfied: click>=4.0 in c:\programdata\anaconda3\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (1.1.1)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (3.0.9)
# Requirement already satisfied: packaging>=23.2 in c:\users\athar\appdata\roaming\python\python311\site-packages (from xarray>=0.19->odc-stac) (24.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->odc-stac) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pandas->odc-stac) (2024.1)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (2023.3.0)
# Requirement already satisfied: partd>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (6.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]->odc-stac) (6.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=4.0->rasterio!=1.3.0,!=1.3.1,>=1.0.0->odc-stac) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[array]->odc-stac) (3.11.0)
# Requirement already satisfied: locket in c:\programdata\anaconda3\lib\site-packages (from partd>=1.2.0->dask[array]->odc-stac) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->pystac<2,>=1.0.0->odc-stac) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install stackstac
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stackstac in c:\users\athar\appdata\roaming\python\python311\site-packages (0.5.1)
# Requirement already satisfied: dask[array]>=2022.1.1 in c:\programdata\anaconda3\lib\site-packages (from stackstac) (2023.6.0)
# Requirement already satisfied: numpy<3,>1.23 in c:\programdata\anaconda3\lib\site-packages (from stackstac) (1.24.3)
# Requirement already satisfied: pandas<3,>=2 in c:\users\athar\appdata\roaming\python\python311\site-packages (from stackstac) (2.2.3)
# Requirement already satisfied: pyproj<4.0.0,>=3.0.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from stackstac) (3.7.1)
# Requirement already satisfied: rasterio<2.0.0,>=1.3.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from stackstac) (1.4.3)
# Requirement already satisfied: xarray>=0.18 in c:\users\athar\appdata\roaming\python\python311\site-packages (from stackstac) (2025.1.2)
# Requirement already satisfied: click>=8.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (2023.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\athar\appdata\roaming\python\python311\site-packages (from dask[array]>=2022.1.1->stackstac) (24.2)
# Requirement already satisfied: partd>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (1.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\programdata\anaconda3\lib\site-packages (from dask[array]>=2022.1.1->stackstac) (6.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<3,>=2->stackstac) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<3,>=2->stackstac) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athar\appdata\roaming\python\python311\site-packages (from pandas<3,>=2->stackstac) (2024.1)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from pyproj<4.0.0,>=3.0.0->stackstac) (2023.7.22)
# Requirement already satisfied: affine in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (2.4.0)
# Requirement already satisfied: attrs in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (25.1.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\athar\appdata\roaming\python\python311\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (1.1.1)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from rasterio<2.0.0,>=1.3.0->stackstac) (3.0.9)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click>=8.0->dask[array]>=2022.1.1->stackstac) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask[array]>=2022.1.1->stackstac) (3.11.0)
# Requirement already satisfied: locket in c:\programdata\anaconda3\lib\site-packages (from partd>=1.2.0->dask[array]>=2022.1.1->stackstac) (1.0.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=2->stackstac) (1.16.0)

# %%
import stackstac

# data1 = stac_load(
#     items,
#     bands=["red", "green", "blue", "nir08"],
#     crs="EPSG:4326", # Latitude-Longitude
#     resolution=scale, # Degrees
#     chunks={"x": 2048, "y": 2048},
#     dtype="uint16",
#     patch_url=planetary_computer.sign,
#     bbox=bounds
# )
# Load the data using stackstac
data1 = stackstac.stack(
    signed_items,
    assets=["red", "green", "blue", "nir08"],
    resolution=scale,
    epsg=4326,  # Latitude-Longitude
    bounds=bounds,
#     chunks={"x": 2048, "y": 2048},
    dtype="float"
)

# %%
data2 = stackstac.stack(
    signed_items,
    assets=["lwir11"],  # The thermal infrared band
    resolution=scale,  # Degrees
    epsg=4326,  # Latitude-Longitude
    bounds=bounds,
    dtype="float"
)

# %% [markdown]
# Since the data matching our query isn't too large we can persist it in distributed memory. Once in memory, subsequent operations will be much faster.

# %%
# View the dimensions of our XARRAY and the loaded variables
# This insures we have the right coordinates and spectral bands in our xarray
display(data1)
display(data2)
# Out:
# <xarray.DataArray 'stackstac-55c522414e547176b62f95c0557feecc' (time: 8,
#                                                                 band: 4,
#                                                                 y: 484, x: 558)> Size: 69MB
# dask.array<fetch_raster_window, shape=(8, 4, 484, 558), dtype=float64, chunksize=(1, 1, 484, 558), chunktype=numpy.ndarray>
# Coordinates: (12/30)
#   * time                         (time) datetime64[ns] 64B 2021-06-07T15:39:1...
#     id                           (time) <U31 992B 'LC08_L2SP_014031_20210607_...
#   * band                         (band) <U5 80B 'red' 'green' 'blue' 'nir08'
#   * x                            (x) float64 4kB -74.01 -74.01 ... -73.86 -73.86
#   * y                            (y) float64 4kB 40.88 40.88 ... 40.75 40.75
#     eo:cloud_cover               (time) float64 64B 6.88 24.54 ... 15.1 8.84
#     ...                           ...
#     raster:bands                 object 8B {'scale': 2.75e-05, 'nodata': 0, '...
#     title                        (band) <U22 352B 'Red Band' ... 'Near Infrar...
#     common_name                  (band) <U5 80B 'red' 'green' 'blue' 'nir08'
#     center_wavelength            (band) float64 32B 0.65 0.56 0.48 0.87
#     full_width_half_max          (band) float64 32B 0.04 0.06 0.06 0.03
#     epsg                         int32 4B 4326
# Attributes:
#     spec:        RasterSpec(epsg=4326, bounds=(-74.0101509162774, 40.74982033...
#     crs:         epsg:4326
#     transform:   | 0.00, 0.00,-74.01|\n| 0.00,-0.00, 40.88|\n| 0.00, 0.00, 1.00|
#     resolution:  0.00026949335249730504
# <xarray.DataArray 'stackstac-48e0928c4d58b7c5c6a02d817c9cdbaa' (time: 8,
#                                                                 band: 1,
#                                                                 y: 484, x: 558)> Size: 17MB
# dask.array<fetch_raster_window, shape=(8, 1, 484, 558), dtype=float64, chunksize=(1, 1, 484, 558), chunktype=numpy.ndarray>
# Coordinates: (12/30)
#   * time                         (time) datetime64[ns] 64B 2021-06-07T15:39:1...
#     id                           (time) <U31 992B 'LC08_L2SP_014031_20210607_...
#   * band                         (band) <U6 24B 'lwir11'
#   * x                            (x) float64 4kB -74.01 -74.01 ... -73.86 -73.86
#   * y                            (y) float64 4kB 40.88 40.88 ... 40.75 40.75
#     eo:cloud_cover               (time) float64 64B 6.88 24.54 ... 15.1 8.84
#     ...                           ...
#     raster:bands                 object 8B {'unit': 'kelvin', 'scale': 0.0034...
#     title                        <U24 96B 'Surface Temperature Band'
#     common_name                  <U6 24B 'lwir11'
#     center_wavelength            float64 8B 10.9
#     full_width_half_max          float64 8B 0.59
#     epsg                         int32 4B 4326
# Attributes:
#     spec:        RasterSpec(epsg=4326, bounds=(-74.0101509162774, 40.74982033...
#     crs:         epsg:4326
#     transform:   | 0.00, 0.00,-74.01|\n| 0.00,-0.00, 40.88|\n| 0.00, 0.00, 1.00|
#     resolution:  0.00026949335249730504

# %%
# Persist the data in memory for faster operations
data1 = data1.persist()
data2 = data2.persist()

# %%
data1 = data1.chunk({"x": 2048, "y": 2048})
data2 = data2.chunk({"x": 2048, "y": 2048})

# %% [markdown]
# ### Scaling Datasets
# Landsat Collection-2 Level-2 products require scaling before creating valid output products. <br>
# Scale factors for the RGB and NIR bands differ from scale factors for the Surface Temperature band.<br>

# %%
# Scale Factors for the RGB and NIR bands 
scale1 = 0.0000275 
offset1 = -0.2 
data1 = data1.astype(float) * scale1 + offset1

# %%
# Scale Factors for the Surface Temperature band
scale2 = 0.00341802 
offset2 = 149.0 
kelvin_celsius = 273.15 # convert from Kelvin to Celsius
data2 = data2.astype(float) * scale2 + offset2 - kelvin_celsius

# %% [markdown]
# ### View RGB (real color) images from the time series
# You will notice that some of the scenes have clouds and some of the scenes have missing data due to scene boundary issues. Since Landsat is a descending orbit path across the equator, the time of acquisition for the scenes below is about 11:30am local time (note the time on the image is UTC time). Also, these images are merely for quick review and are not scaled correctly to reflect the proper Lat-Lon ratios.

# %%
data1
# Out:
# <xarray.DataArray 'stackstac-55c522414e547176b62f95c0557feecc' (time: 8,
#                                                                 band: 4,
#                                                                 y: 484, x: 558)> Size: 69MB
# dask.array<add, shape=(8, 4, 484, 558), dtype=float64, chunksize=(1, 1, 484, 558), chunktype=numpy.ndarray>
# Coordinates: (12/30)
#   * time                         (time) datetime64[ns] 64B 2021-06-07T15:39:1...
#     id                           (time) <U31 992B dask.array<chunksize=(8,), meta=np.ndarray>
#   * band                         (band) <U5 80B 'red' 'green' 'blue' 'nir08'
#   * x                            (x) float64 4kB -74.01 -74.01 ... -73.86 -73.86
#   * y                            (y) float64 4kB 40.88 40.88 ... 40.75 40.75
#     eo:cloud_cover               (time) float64 64B dask.array<chunksize=(8,), meta=np.ndarray>
#     ...                           ...
#     raster:bands                 object 8B {'scale': 2.75e-05, 'nodata': 0, '...
#     title                        (band) <U22 352B dask.array<chunksize=(4,), meta=np.ndarray>
#     common_name                  (band) <U5 80B dask.array<chunksize=(4,), meta=np.ndarray>
#     center_wavelength            (band) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
#     full_width_half_max          (band) float64 32B dask.array<chunksize=(4,), meta=np.ndarray>
#     epsg                         int32 4B 4326

# %%
plot_data = data1.sel(band=["red","green","blue"])
plot_data.plot.imshow(col='time', col_wrap=4, robust=True, vmin=0, vmax=0.25)
plt.show()

# %% [markdown]
# ### Output Products
#
# We will pick the best the best scene (no clouds, no missing data) to build our output products. This will not require any median filtering calculations as we will just pick one date from the time series. Finally, the numbering for these scenes starts at ZERO and goes from the top-left across the rows to reach the total number of scenes in the data array shown above.

# %%
# Pick one of the scenes above (numbering starts with 0)
scene = 2

# %%
print(data1[["red", "green", "blue"]].min())
print(data1[["red", "green", "blue"]].max())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 print(data1[["red", "green", "blue"]].min())
#       2 print(data1[["red", "green", "blue"]].max())
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\core\dataarray.py:904, in DataArray.__getitem__(self, key)
#     901     return self._getitem_coord(key)
#     902 else:
#     903     # xarray-style array indexing
# --> 904     return self.isel(indexers=self._item_key_to_dict(key))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\core\dataarray.py:1538, in DataArray.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1535 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    1537 if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 1538     ds = self._to_temp_dataset()._isel_fancy(
#    1539         indexers, drop=drop, missing_dims=missing_dims
#    1540     )
#    1541     return self._from_temp_dataset(ds)
#    1543 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1544 # lists, or zero or one-dimensional np.ndarray's
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\core\dataset.py:3139, in Dataset._isel_fancy(self, indexers, drop, missing_dims)
#    3132 def _isel_fancy(
#    3133     self,
#    3134     indexers: Mapping[Any, Any],
#    (...)
#    3137     missing_dims: ErrorOptionsWithWarn = "raise",
#    3138 ) -> Self:
# -> 3139     valid_indexers = dict(self._validate_indexers(indexers, missing_dims))
#    3141     variables: dict[Hashable, Variable] = {}
#    3142     indexes, index_variables = isel_indexes(self.xindexes, valid_indexers)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\core\dataset.py:2914, in Dataset._validate_indexers(self, indexers, missing_dims)
#    2912 index = self._indexes[k].to_pandas_index()
#    2913 if isinstance(index, pd.DatetimeIndex):
# -> 2914     v = duck_array_ops.astype(v, dtype="datetime64[ns]")
#    2915 elif isinstance(index, CFTimeIndex):
#    2916     v = _parse_array_of_cftime_strings(v, index.date_type)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\core\duck_array_ops.py:236, in astype(data, dtype, **kwargs)
#     234         return data.astype(dtype, **kwargs)
#     235     return xp.astype(data, dtype, **kwargs)
# --> 236 return data.astype(dtype, **kwargs)
#
# ValueError: Error parsing datetime string "red" at position 0

# %%
# Plot an RGB Real Color Image for a single date
fig, ax = plt.subplots(figsize=(9,10))
plot_data = data1.isel(time=scene).sel(band=["red", "green", "blue"])

plot_data.plot.imshow(robust=True, ax=ax, vmin=0.0, vmax=0.25)
ax.set_title("RGB Real Color")
ax.axis('off')
plt.show()

# %% [markdown]
# The <b>Normalized Difference Vegetation Index (NDVI)</b> is used to measure the "greenness" of vegetation and has a range of 0.0 to 1.0. Low values (0.0 to 0.25) reflect a lack of vegetation (bare soil, urban, water), middle values (0.25 to 0.6) reflect grasslands or croplands in their growing state, and high values (0.6 to 1.0) reflect dense vegetation such as trees or croplands at their peak vegetation state. Such information can be relevant to modeling urban heating as the proximity to vegetation or "green space" can mitigate urban heating. The equation uses two spectral bands where: <b>NDVI = (NIR-Red) / (NIR+Red).

# %%
# Calculate NDVI for the median mosaic
ndvi_data = (data1.isel(time=scene).nir08-data1.isel(time=scene).red)/(data1.isel(time=scene).nir08+data1.isel(time=scene).red)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 # Calculate NDVI for the median mosaic
# ----> 2 ndvi_data = (data1.isel(time=scene).nir08-data1.isel(time=scene).red)/(data1.isel(time=scene).nir08+data1.isel(time=scene).red)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\xarray\core\common.py:305, in AttrAccessMixin.__getattr__(self, name)
#     303         with suppress(KeyError):
#     304             return source[name]
# --> 305 raise AttributeError(
#     306     f"{type(self).__name__!r} object has no attribute {name!r}"
#     307 )
#
# AttributeError: 'DataArray' object has no attribute 'nir08'

# %%
fig, ax = plt.subplots(figsize=(11,10))
ndvi_data.plot.imshow(vmin=0.0, vmax=1.0, cmap="RdYlGn")
plt.title("Vegetation Index = NDVI")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Landsat Surface Temperature

# %%
fig, ax = plt.subplots(figsize=(11,10))
data2.isel(time=scene).lwir11.plot.imshow(vmin=20.0, vmax=45.0, cmap="jet")
plt.title("Land Surface Temperature (LST)")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Save the output data in a GeoTIFF file

# %%
# Only select one of the time slices to output
data3 = data2.isel(time=scene)

# %%
filename = "Landsat_LST.tiff"

# %%
# Calculate the dimensions of the file
height = data3.dims["latitude"]
width = data3.dims["longitude"]

# %%
# Define the Coordinate Reference System (CRS) to be common Lat-Lon coordinates
# Define the tranformation using our bounding box so the Lat-Lon information is written to the GeoTIFF
gt = rasterio.transform.from_bounds(lower_left[1],lower_left[0],upper_right[1],upper_right[0],width,height)
data3.rio.write_crs("epsg:4326", inplace=True)
data3.rio.write_transform(transform=gt, inplace=True);

# %%
# Create the GeoTIFF output file using the defined parameters 
with rasterio.open(filename,'w',driver='GTiff',width=width,height=height,
                   crs='epsg:4326',transform=gt,count=1,compress='lzw',dtype='float64') as dst:
    dst.write(data3.lwir11,1)
    dst.close()

# %%
# Show the new saved output file
# !ls *.tiff
